# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# Some nice researched stuff
#
# https://www.evernote.com/shard/s424/sh/136ec5b8-53a6-69cf-933c-000bc97d4617/edd3faa4c8b55e8250e7094738d1090d

# %% [markdown]
# #### Now some infos:

# %% [markdown]
# From https://www.buildingmaterials.co.uk/plasterboard/plasterboard/fire-resistant?product_list_limit=48
#
# ## Fire Resistant
#
# **Fire resistant plasterboard**, commonly known as **fireproof plasterboard**, is quite self-explanatory. The boards can be used for both walls and ceilings.
#
# These plasterboards benefit greatly from **enhanced fireproof qualities** that have been added to the board. The **British Gypsum Fireline** square edge plasterboard consists of an aerated core with glass fibres and other insulant material additives encased in the strong paper liners. This board is best suited for dry lining internal surfaces.
#
# The **fire resistance performance** of plasterboard is based on several building ‘elements’. These elements include walls, floors, ceilings and partitions. Plasterboard in this instance only forms part of these overall constructions. **HTM05** and **BB100** documents require a minimum period of fire resistance provided by these ‘elements’.
#
# No matter the ‘element’, the linings in the plasterboard will have metal studs and screw fixings which also make up the whole ‘system’ of fire resistance performance. All components make up the performance (expressed in periods of **resistance** in **minutes** – usually from **30-120**). Plasterboard cannot be considered fire resistant on its own.
#
# Our **fire rated plasterboard sheets** come in widths of either **12.5mm** or **15mm** and are available in **tapered edge** or **square edge** styles. The latter thickness is ideal for walls and partitioning where a more robust barricade with fire protection is required.
#
# However, we strongly recommend getting in touch directly prior to ordering square edge boards, due to minimal stock levels around the country, and that square edge is significantly less popular than tapered edge for fire protection projects. Be advised that square edge fire retardant plasterboard will take a few extra days to be delivered.
#
# Partition fire testing is carried out in accordance with **BS476**.

# %% [markdown]
# From https://www.insulationshop.co/fire_resistant_insulation_buy_online/fire_protection_boards.html?page=1
#
# ## Fire Protection Boards
#
#
# Fire, like air and water is very useful for us, but the devastation fire causes can be catastrophic. Special types of fire resistant boards are created to safeguard your building from fire hazard. This is called the passive fire protection. The aim of of passive fire protection system is to contain the fire by delaying the growth of the fire and to prevent the fire and smoke from moving from one compartment to another and to delay the collapse of the building structure.
#
#
# Fire protection boards are made from Calcium Silicate, Gypsum, and Mineral Fibre with special additives to suppress the growth of fire. These boards have excellent stability, are easily installed, have fire performance and finish in one and have up to 240 minutes fire performance. Some of these boards have moisture resistance additives in them, so they can be installed in areas, where there is a chance of exposure to moisture or water. The fire protection boards are also used in industrial, commercial and public areas, such as factories, duct work, steel structures, smoke barriers, tunnels, airports.
#
# A good building is a safe building. Fire safety of a building is very important and all buildings have to meet the legislation regarding fire-safe construction, so using superior quality fire protection materials is crucial. During a fire, fire rated constructions allow people to reach safety. The manufacturers of specialised fire protection boards test them thoroughly. Carefully selected fire protection boards are available at Insulationshop.co.
#
# ### Fire protection testing
#
# Reaction to Fire - tests how a product will become involved in the growth of fire at origin, up to the time when flashover--near-simultaneous ignition of the material directly exposed to fire--occurs, or does not occur, and provides a fire classification for the material.
# Fire resistance - tests how an element of construction or fire protection system will prevent a fully developed fire from causing structural collapse of the element, or prevent the fire from passing from origin into an adjacent space.
#
#
# ### Tests on materials
#
#
# Non-combustibility test for materials: BS 476: Part 4: 1970 - This test classifies materials as either non-combustible or combustible. It is standard for the fire performance of materials and gives a measure of the heat and flames generated by the material under standard heating conditions. Non-combustible materials can be used without restriction anywhere in a building, as their use ensures that hazards due to smoke and toxic gases are minimised and that the fabric of a building will not contribute to creating a fire.
# Method of test for fire propagation for products: BS 476: Part 6: 1989 - This test measures the amount and rate of heat evolved by the product while subjected to standard heating conditions.
# Method for classification of the surface spread of flame for products: BS 476: Part 7: 1987 - This test classifies materials into Classes 1 to 4 in descending order of performance according to the rate and extent of flame spread over their surface under standard heating conditions. Class 1 is the highest.
# Method of assessing the heat emissions from building materials: BS 476: Part 11: 1982 - This is method for assessing the heat emissions from building materials at a temperature of 750C. Class 0 - Composed throughout of materials of limited combustibility.
#
# Fire performance of the material is tested on,
# * its ability support its loadbearing capacity without deformation,
# * its integrity against collapsing, freedom from holes, cracks and fissures and sustained flaming on the unexposed face,
# * its ability to restrict the temperature rise of the unexposed face to below specified levels (usually 140C mean rise, 180C maximum rise),
# * its ability to maintain its intended function.
#
# ### Types of Application
# * Partitions,
# * Ceilings,
# * Wall and roof linings,
# * Door upgrades,
# * Porch or canopy linings,
# * Service enclosures and pipe covers,
# * Boiler and airing cupboard linings,
# * Service shafts, lift enclosures, cavity barriers, smoke plenums,
# * Valve box enclosures,
# * Fuel pipe protection,
# * Fire doors,
# * Fire protection of structural steelwork
#
# ### Recommended products
# * 30 - 90 minute fire protection - Promat MASTERBOARD, a calcium silicate board reinforced with selected fibres available in 6mm, 9mm and 12mm thickness. PROMATECT L500 is a non-combustible low density calcium silicate board, thicknesses 2x25mm (30mins), 2x30mm (60mins), 2x40 (90mins). Versapanel Cement Bonded Particle Board with 60 mins fire protection available in 10mm, 12mm, 18mm and 22mm thickness.
# * 120 minute fire protection - Kemwell MP-1000, a calcium silicate board available in 9mm and 12mm thickness. PROMATECT L500 2x50mm for 2 hours fire protection. Knauf Fireshield, a gypsum board - 2 sheets would give 2 hours of fire protection. Gyproc FireLine MR Plasterboard, a gypsum board available in 12.5mm and 15mm thickness.
# * 240 minute fire protection - Promat SUPALUX, a calcium silicate board available in 6mm, 9mm, 12mm and 15mm thickness. Promat Monolux 250, 500 and 800 available in 12.7mm, 19.1mm and 25.4mm thickness

# %% [markdown]
# ## Other resources:
#
# https://www.insulationsuperstore.co.uk/browse/plasterboard/gyproc-wallboard-plasterboard.html

# %% [markdown]
# ## <span style="color:red"> Still have to find for some cement ones. </span>
#
# * StoneREX

# %% [markdown]
# ## <span style="color:green"> Buying in bulk cuts prices.
# </span>

# %% [markdown]
# # A note

# %% [markdown]
# ### There is a big variety here, with multinationals....
#
# Saint-Goban offers incentives, see here https://www.saint-gobain.co.uk/green-homes-grant-solutions
#
#
# Norbord was recently acquired...
# - West Fraser Timber to Acquire 100% Stake in Norbord, Announced Date 19-11-2020
# 	- West Fraser to acquire Norbord, creating a diversified global wood products leader for approximately C$4.0 billion
# 	- Source: https://advantage-marketline-com.proxy.jbs.cam.ac.uk/Deals/Facts/newswires-dealstopc-manda-west-fraser-to-acquire-norbord-creating-a-diversified-global-wood-products-leader-for-approximately-c40-billion_2455180
#
#
# ## How can we make ourselves competitive?
#
#
# ## <span style="color:red"> What is our niche? </span>

# %% [markdown]
# # Databases, 06/01/2020

# %%
df0 = pd.read_csv('scrapedv0')
df = df0
df
# Out:
#     Unnamed: 0                                         Name  Length (mm)  \
# 0            0        British Gypsum GYPROC Fireline Duplex       2400.0
# 1            1            British Gypsum GYPROC Fireline MR       3000.0
# 2            2                              GTEC Fire Board       1800.0
# 3            3                              GTEC Fire Board       1800.0
# 4            4                              GTEC Fire Board       1800.0
# 5            5                              GTEC Fire Board       2400.0
# 6            6                              GTEC Fire Board       2400.0
# 7            7                              GTEC Fire Board       2400.0
# 8            8                              GTEC Fire Board       2700.0
# 9            9                              GTEC Fire Board       2700.0
# 10          10                              GTEC Fire Board       3000.0
# 11          11                              GTEC Fire Board       3000.0
# ...

# %%
df0 = df0.drop(0)
df = df0

# %%
unique_labels = df0['Name'].unique()
unique_labels
# Out:
# array(['British Gypsum GYPROC Fireline MR', 'GTEC Fire Board',
#        'GTEC Fire Core Board', 'GTEC Fire MR Board', 'GTEC Fire V Board',
#        'GTEC LaDura', 'GTEC Megadeco', 'GTEC Universal Board',
#        'Knauf Fire Panel', 'Fireproof Plasterboard',
#        'British Gypsum Gyproc Fireline Plasterboard'], dtype=object)

# %%
means = []

# %%
for u in unique_labels:
    means += [df0[df0['Name'] == u].mean()['Price VAT (£)']]

# %%
a4_dims = (20, 10)

sns.set(font_scale = 2)

plt.rc('font', family='serif')

fig, ax = plt.subplots(figsize = a4_dims)

ax.set_xlabel(xlabel = '', fontsize = 25)

sns.set(font_scale = 10)

ax.set_xticks(range(0,100, 10))

b = sns.barplot(data = df0, y = "Name", x = "Price VAT (£)", palette = 'Greens_r')

ax.set_ylabel(ylabel = 'Product', fontsize = 25)

plt.savefig('prices-sns_1.png', bbox_inches = 'tight', transparent = True, dpi = 300)

# %%
df.to_excel('prices_database_1.xlsx')

# %%
df = pd.read_csv('scrapedv1')
testo = 'Ignored the following from the website [1 Sheet  coverage, Pallet Coverage, Volume, Edge Profile, Surface Spread of Flame, Colour, Pallet Quantity, Temperature resistance]'
print(testo)
df
# Out:
# Ignored the following from the website [1 Sheet  coverage, Pallet Coverage, Volume, Edge Profile, Surface Spread of Flame, Colour, Pallet Quantity, Temperature resistance]
#     Unnamed: 0                                               Name  \
# 0            0    19.1mm Promat Monolux 500 Fire Protection Board
# 1            1  1.5kg Promafour-HT Joint Filler - Fire Protect...
# 2            2  12.5mm Fire Panel (formerly known as Fireshiel...
# 3            3  12.5mm Gyproc FireLine MR Plasterboard 1200mm ...
# 4            4  12.5mm Knauf Performance Plus - High Performan...
# 5            5  12.5mm Knauf Performance Plus - High Performan...
# 6            6    12.7mm Promat Monolux 500 Fire Protection Board
# 7            7    12.7mm Promat Monolux 800 Fire Protection Board
# 8            8  12mm Kemwell MP-1000 Multipurpose Calcium Sili...
# 9            9                          12mm Masterboard Promat
# 10          10  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# ...

# %%
df.loc[0]['R-Value m2K/W']
# Out:
# nan

# %%
df_not_nan = df.dropna(subset = ['Thickness (mm)', 'Fire Rating (Reaction to Fire)'])
df = df_not_nan
df
# Out:
#     Unnamed: 0                                               Name  \
# 0            0    19.1mm Promat Monolux 500 Fire Protection Board
# 3            3  12.5mm Gyproc FireLine MR Plasterboard 1200mm ...
# 4            4  12.5mm Knauf Performance Plus - High Performan...
# 5            5  12.5mm Knauf Performance Plus - High Performan...
# 6            6    12.7mm Promat Monolux 500 Fire Protection Board
# 7            7    12.7mm Promat Monolux 800 Fire Protection Board
# 8            8  12mm Kemwell MP-1000 Multipurpose Calcium Sili...
# 9            9                          12mm Masterboard Promat
# 10          10  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# 11          11  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# 12          12          12mm Supalux Promat Fire Protection Board
# 15          15  15mm Gyproc FireLine MR Plasterboard 1200mm x ...
# 16          16  15mm Knauf Fireboard - High Performance Plaste...
# ...

# %%
df['Fire Rating (Reaction to Fire)']
# Out:
# 0             A1(Non-combustible)
# 3      A2(Limited combustibility)
# 4      A2(Limited combustibility)
# 5      A2(Limited combustibility)
# 6             A1(Non-combustible)
# 7             A1(Non-combustible)
# 8             A1(Non-combustible)
# 9      A2(Limited combustibility)
# 10            A1(Non-combustible)
# 11            A1(Non-combustible)
# 12            A1(Non-combustible)
# 15     A2(Limited combustibility)
# 16            A1(Non-combustible)
# 17     A2(Limited combustibility)
# 18     A2(Limited combustibility)
# 19            A1(Non-combustible)
# 20            A1(Non-combustible)
# 21            A1(Non-combustible)
# 22     A2(Limited combustibility)
# 23            A1(Non-combustible)
# 24            A1(Non-combustible)
# 25            A1(Non-combustible)
# 26            A1(Non-combustible)
# 28            A1(Non-combustible)
# 29            A1(Non-combustible)
# 31            A1(Non-combustible)
# 32            A1(Non-combustible)
# ...

# %%
types = []

fire_ratings = []

brands = []

A1 = 'A1'
A2 = 'A2'

gp = 'Gypsum Plasterboard'
cs = 'Calcium Silicate'

K = 'Knauf'
B = 'British Gypsium'
G = 'GTEC Fire'
KM = 'Kemwell'
P = 'Promat'

for n, rating in zip(df['Name'], df['Fire Rating (Reaction to Fire)']):
    if A1 in rating:
        fire_ratings += [A1]
    elif A2 in rating:
        fire_ratings += [A2]
    else:
        print('None values', rating)
    if 'Promat' in n:
        brands += [P]
        types += [cs]
    elif 'Gyproc' in n:
        brands += [B]
        types += [gp]
    elif 'Glasroc' in n:
        brands += [B]
        types += [gp]
    elif 'Knauf' in n:
        brands += [K]
        types += [gp]
    elif 'Kemwell' in n:
        brands += [KM]
        types += [cs]
    else:
        types += ['None']
        print('None values', n)
types
# Out:
# ['Calcium Silicate',
#  'Gypsum Plasterboard',
#  'Gypsum Plasterboard',
#  'Gypsum Plasterboard',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Gypsum Plasterboard',
#  'Gypsum Plasterboard',
#  'Gypsum Plasterboard',
#  'Gypsum Plasterboard',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Gypsum Plasterboard',
#  'Gypsum Plasterboard',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Gypsum Plasterboard',
#  'Calcium Silicate',
#  'Gypsum Plasterboard',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate',
#  'Calcium Silicate']

# %%
df.sort_values('Price VAT (£)', ascending = False)
# Out:
#     Unnamed: 0                                               Name  \
# 40          40      50mm Promat Monolux 800 Fire Protection Board
# 32          32     30mm Promat Monolux 800 Fire Protection Board
# 26          26  25.4mm Promat Monolux 500 Fire Protection Boar...
# 24          24      20mm Promat Monolux 800 Fire Protection Board
# 0            0    19.1mm Promat Monolux 500 Fire Protection Board
# 6            6    12.7mm Promat Monolux 500 Fire Protection Board
# 7            7    12.7mm Promat Monolux 800 Fire Protection Board
# 21          21          15mm Supalux Promat Fire Protection Board
# 11          11  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# 12          12          12mm Supalux Promat Fire Protection Board
# 9            9                          12mm Masterboard Promat
# 15          15  15mm Gyproc FireLine MR Plasterboard 1200mm x ...
# 3            3  12.5mm Gyproc FireLine MR Plasterboard 1200mm ...
# ...

# %%
df['Type'] = types
df['Fire Rating'] = fire_ratings
df['Brand'] = brands
# Out:
# /Users/omardarwish/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/omardarwish/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/omardarwish/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfnew = df[['Name', 'Price VAT (£)', 'Type', 'Fire Rating', 'Brand', 'Fire Protection (Resistance to Fire) (min)', 'Weight/m^2 (kg)']].copy()

# %%
dfnew_ = dfnew[dfnew['Price VAT (£)']<300]

# %%
a4_dims = (30, 20)

fig, ax = plt.subplots(figsize = a4_dims)

plt.rc('font', family = 'serif')

ax.set_xlabel(xlabel = '', fontsize = 25)
ax.set_ylabel(ylabel = '', fontsize = 25)

ax.set_xticks(range(0,800, 25))

sns.set(font_scale = 2)
ax = sns.scatterplot(data = dfnew_, x = 'Price VAT (£)', y = 'Weight/m^2 (kg)', 
                hue = 'Fire Rating', palette = ['blue', 'lightblue'], style = 'Type', s = 600)

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis = 1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(dfnew_['Price VAT (£)'], dfnew_['Weight/m^2 (kg)'], dfnew_['Brand'], plt.gca()) 

#sns.scatterplot(x="total_bill", y="tip",
#                     hue="day", style="time", data=tips)


plt.savefig('prices-hist.png', bbox_inches = 'tight', dpi = 200)

# %%
dfnew.keys()
# Out:
# Index(['Name', 'Price VAT (£)', 'Type', 'Fire Rating', 'Brand',
#        'Fire Protection (Resistance to Fire) (min)', 'Weight/m^2 (kg)'],
#       dtype='object')

# %%
dfnew['Price VAT (£)']
# Out:
# 0     359.04
# 3      23.17
# 4      17.04
# 5        NaN
# 6     354.00
# 7     271.93
# 8        NaN
# 9     182.60
# 10       NaN
# 11    238.73
# 12    188.15
# 15     25.19
# 16       NaN
# 17     22.56
# 18       NaN
# 19       NaN
# 20       NaN
# 21    267.46
# 22     22.87
# 23       NaN
# 24    408.98
# 25       NaN
# 26    457.93
# 28       NaN
# 29       NaN
# 31       NaN
# 32    459.30
# 33       NaN
# 35       NaN
# 36       NaN
# 38       NaN
# 39       NaN
# 40    700.73
# 41       NaN
# 42       NaN
# Name: Price VAT (£), dtype: float64

# %%
import numpy as np

# %%
a4_dims = (30, 20)

sns.set(font_scale = 2)

plt.rc('font', family='serif')

fig, ax = plt.subplots(figsize = a4_dims)

ax.set_xlabel(xlabel = '', fontsize = 25)


sns.set(font_scale = 10)

ax.set_xticks(range(0,800, 25))

b = sns.barplot(data = dfnew.dropna(subset = ['Price VAT (£)']), y = "Name", x = "Price VAT (£)", palette = 'Greens_r')

ax.set_ylabel(ylabel = 'Product', fontsize = 25)

plt.savefig('prices-sns_2.png', bbox_inches = 'tight', transparent = True, dpi = 200)

# %%
df0new = df.dropna(subset = ['Fire Protection (Resistance to Fire) (min)'])

# %%
a4_dims = (30, 20)

sns.set(font_scale = 2)

plt.rc('font', family='serif')

fig, ax = plt.subplots(figsize = a4_dims)

ax.set_xlabel(xlabel = '', fontsize = 25)

sns.set(font_scale = 10)

ax.set_xticks(range(0,300, 10))

clrs = ['blue' if (A1 in x) else 'lightblue' for x in dfnew['Fire Rating']]

b = sns.barplot(data = df0new, y = "Name", x = "Fire Protection (Resistance to Fire) (min)", hue = 'Fire Rating', palette = ['blue', 'lightblue'])#palette = clrs)

ax.set_ylabel(ylabel = 'Product', fontsize = 25)

ax.legend(fontsize = 80)

plt.savefig('fires-sns_2.png', bbox_inches = 'tight', transparent = True, dpi = 200)

# %% [markdown]
# ### Sort by Fire Protection (Resistance to Fire) (min)

# %%
sorteddf = df.sort_values('Fire Protection (Resistance to Fire) (min)', ascending = False)
sorteddf
# Out:
#     Unnamed: 0                                               Name  \
# 0            0    19.1mm Promat Monolux 500 Fire Protection Board
# 26          26  25.4mm Promat Monolux 500 Fire Protection Boar...
# 29          29      25mm Promat Monolux 800 Fire Protection Board
# 20          20  15mm Promat PROMAFOUR Non-Combustible Fire Res...
# 19          19  15mm Promat PROMAFOUR Non-Combustible Fire Res...
# 32          32     30mm Promat Monolux 800 Fire Protection Board
# 36          36   38.1mm Promat Monolux 500 Fire Protection Board
# 39          39   50.8mm Promat Monolux 500 Fire Protection Board
# 11          11  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# 10          10  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# 40          40      50mm Promat Monolux 800 Fire Protection Board
# 7            7    12.7mm Promat Monolux 800 Fire Protection Board
# 6            6    12.7mm Promat Monolux 500 Fire Protection Board
# ...

# %%
df.to_excel('prices_database_2.xlsx')

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
sorteddf.loc[0,'Price No VAT (£)']
# Out:
# 299.2

# %%
fireprot = 'Fire Protection (Resistance to Fire) (min)'

axes = sorteddf.plot.bar('Unnamed: 0', fireprot, figsize = (35, 10))

keys = np.array(sorteddf['Unnamed: 0'])

for i, p in enumerate(axes.patches):
    price = sorteddf.loc[keys[i] ,'Price No VAT (£)']
    axes.annotate(str(round(price, 2)), (p.get_x() * 1.005, p.get_height() * 1.005))
        
        
plt.gcf().autofmt_xdate()
plt.show()

# %%
selection = df[fireprot]>= 240
higherfiremin = df[selection]
higherfiremin
# Out:
#     Unnamed: 0                                               Name  \
# 0            0    19.1mm Promat Monolux 500 Fire Protection Board
# 6            6    12.7mm Promat Monolux 500 Fire Protection Board
# 7            7    12.7mm Promat Monolux 800 Fire Protection Board
# 10          10  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# 11          11  12mm Promat PROMAFOUR Non-Combustible Fire Res...
# 19          19  15mm Promat PROMAFOUR Non-Combustible Fire Res...
# 20          20  15mm Promat PROMAFOUR Non-Combustible Fire Res...
# 24          24      20mm Promat Monolux 800 Fire Protection Board
# 26          26  25.4mm Promat Monolux 500 Fire Protection Boar...
# 29          29      25mm Promat Monolux 800 Fire Protection Board
# 32          32     30mm Promat Monolux 800 Fire Protection Board
# 36          36   38.1mm Promat Monolux 500 Fire Protection Board
# 39          39   50.8mm Promat Monolux 500 Fire Protection Board
# ...

# %%
axes = higherfiremin.plot.bar('Name', fireprot, title = 'Markers with 240 min', fontsize = 30, figsize = (25, 20))

keys = np.array(higherfiremin['Unnamed: 0'])

for i, p in enumerate(axes.patches):
    price = higherfiremin.loc[keys[i] ,'Price No VAT (£)']
    axes.annotate(str(round(price, 2)), (p.get_x() * 1.005, p.get_height() * 1.005), fontsize = 20)
        
axes.title.set_size(40)
        
plt.gcf().autofmt_xdate()
plt.show()

# %%
selection = df[fireprot]<= 30
lowfiremin = df[selection]
lowfiremin
# Out:
#     Unnamed: 0                                       Name  Thickness (mm)  \
# 9            9                  12mm Masterboard Promat              12.0
# 43          43                     6mm Masterboard Promat             NaN
# 44          44  6mm Supalux Promat Fire Protection Board              NaN
# 46          46                   9mm Masterboard Promat               NaN
# 47          47   9mm Supalux Promat Fire Protection Board             NaN
#
#     Width (mm)  Length (mm) Area (m^2)  Density (kg/m^3)  Weight/m^2 (kg)  \
# 9       1220.0       2440.0        2.9            1000.0             12.0
# 43      1220.0       2440.0        2.9            1000.0              NaN
# 44      1220.0       2440.0        2.9             950.0              5.7
# 46      1220.0       2440.0        2.9            1000.0              NaN
# 47      1220.0       2440.0        2.9             950.0              8.5
#
#     Weight (kg)  Thermal Conductivity (W/mK)  Compressive Strength (kPa)  \
# ...

# %%
axes = lowfiremin.plot.bar('Name', fireprot, title = 'Markers with less or equal than 30 min', fontsize = 30, figsize = (25, 20))

keys = np.array(lowfiremin['Unnamed: 0'])

for i, p in enumerate(axes.patches):
    price = lowfiremin.loc[keys[i] ,'Price No VAT (£)']
    axes.annotate(str(round(price, 2)), (p.get_x() * 1.005, p.get_height() * 1.005), fontsize = 20)
        
axes.title.set_size(40)

        
plt.gcf().autofmt_xdate()
plt.show()
